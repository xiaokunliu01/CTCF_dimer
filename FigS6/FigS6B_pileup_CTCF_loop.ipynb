# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 300
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os, subprocess

from coolpuppy import coolpup
from coolpuppy.lib import numutils
from coolpuppy.lib.puputils import divide_pups
from coolpuppy import plotpup
import cooler
import bioframe
import cooltools
from cooltools import expected_cis, expected_trans
from cooltools.lib import plotting

# %%
resolution = 5000
flank=200000

# %%
clr_1 = cooler.Cooler(f'DNaseC_C2D5_blk.mcool::/resolutions/{resolution}')
clr_2 = cooler.Cooler(f'DNaseC_C2D5_hCTCF.mcool::/resolutions/{resolution}')
clr_3 = cooler.Cooler(f'DNaseC_C2D5_66.mcool::/resolutions/{resolution}')
clr_4 = cooler.Cooler(f'DNaseC_C2D5_132.mcool::/resolutions/{resolution}')
clr_5 = cooler.Cooler(f'DNaseC_C2D5_198.mcool::/resolutions/{resolution}')
clr_6 = cooler.Cooler(f'DNaseC_C2D5_265.mcool::/resolutions/{resolution}')

# %%
hg38_chromsizes = bioframe.fetch_chromsizes('hg38')
hg38_cens = bioframe.fetch_centromeres('hg38')
hg38_arms = bioframe.make_chromarms(hg38_chromsizes, hg38_cens)

hg38_arms = hg38_arms.set_index("chrom").loc[clr_1.chromnames].reset_index()

hg38_arms = bioframe.make_viewframe(hg38_arms)

# %%
# sites = bioframe.read_table('/mnt/disk5/1/DNaseC/total/293T/regular_file/DNaseC_293T_total_UMI_wlink_nochrCLMT_noheader.bedpe', schema='bedpe')
# sites = bioframe.read_table('/mnt/disk5/1/DNaseC/total/R3D7/regular_file/dTAG4h/DNaseC_R3D7_dTAG4h_UMI_rmdup_noheader.bedpe', schema='bedpe')

# sites = bioframe.read_table('/mnt/disk5/1/DNaseC/total/R3D7/regular_file/DMSO4h/DNaseC_R3D7_DMSO4h_UMI_rmdup_noheader.bedpe', schema='bedpe')

#sites = ctcf.sort_values('score', ascending=False).head(1000)

sites = bioframe.read_table('/mnt/disk1/6/lxk/private/DNase-C/dimer_paper/fig4/pileup/R2/CTCF_loop.bedpe', schema='bedpe')

# %%
expected_1 = expected_cis(
    clr_1,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_1 = coolpup.pileup(
    clr_1,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_1,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_1 = plotpup.plot(
    pup_1,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_1.savefig('blk.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
expected_2 = expected_cis(
    clr_2,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_2 = coolpup.pileup(
    clr_2,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_2,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_2 = plotpup.plot(
    pup_2,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_2.savefig('hCTCF.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
# pup_divide_1 = divide_pups(pup_2, pup_1)

# fig_divide_1 = plotpup.plot(
#     pup_divide_1,
#     score=True,
#     cmap='coolwarm',
#     scale='log',
#     sym=True,
#     vmax=5,
#     vmin=0.2,
#     height=2,
#     plot_ticks=True
# )

# # fig_divide_1.savefig('R3D7_dTAG-DMSO.pdf')

# %%
expected_3= expected_cis(
    clr_3,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_3 = coolpup.pileup(
    clr_3,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_3,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_3 = plotpup.plot(
    pup_3,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_3.savefig('66.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
expected_4 = expected_cis(
    clr_4,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_4 = coolpup.pileup(
    clr_4,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_4,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_4 = plotpup.plot(
    pup_4,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_4.savefig('132.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
# pup_divide_2 = divide_pups(pup_4, pup_3)

# fig_divide_2 = plotpup.plot(
#     pup_divide_2,
#     score=True,
#     cmap='coolwarm',
#     scale='log',
#     sym=True,
#     vmax=5,
#     vmin=0.2,
#     height=2,
#     plot_ticks=True
# )

# # fig_divide_2.savefig('C2D5_dTAG-DMSO.pdf')

# %%
expected_5 = expected_cis(
    clr_5,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_5 = coolpup.pileup(
    clr_5,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_5,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_5 = plotpup.plot(
    pup_5,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_5.savefig('198.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
expected_6 = expected_cis(
    clr_6,
    ignore_diags=2,
    view_df=hg38_arms,
    chunksize=1000000,
    nproc=80
)

# %%
pup_6 = coolpup.pileup(
    clr_6,
    sites,
    features_format='bedpe',
    view_df=hg38_arms,
#     local=True,
#     flip_negative_strand=True,
    expected_df=expected_6,
#     nshifts=10,
    flank=flank,
    mindist=5000,
#     maxdist=600_000,
#     subset=2000,
#     seed=1,
    min_diag=2,
    nproc=80
)
# Out:
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 177
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 702
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 636
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 229
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 581
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 207
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 477
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 531
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 418
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 465
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 124
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 391
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 141
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 239
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 68
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 385
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 245
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 169
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 158
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 399
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 163
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 221
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 742
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 159
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 215
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 482
# INFO:coolpuppy:('chr4_p', 'chr4_p'): 185
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 559
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 143
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 581
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 375
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 687
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 342
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 503
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 189
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 441
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 183
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 495
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 205
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 410
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 284
# INFO:coolpuppy:Total number of piled up windows: 14306

# %%
fig_6 = plotpup.plot(
    pup_6,
    score=True,
    cmap='coolwarm',
    scale='log',
    sym=True,
    vmax=3.0,
    vmin=0.33,
    height=2,
    plot_ticks=True
)

fig_6.savefig('265.pdf')
# Out:
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
